# %%
import pandas as pd

# %%
df = pd.read_csv('wine_cleaned.csv', index_col =0)

# %%
df.head(2)
# Out:
#     country                                        description designation  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...         NaN
#
#    points  price province           region_1           region_2   taster_name  \
# 1      87   15.0    Douro                NaN                NaN    Roger Voss
# 2      87   14.0   Oregon  Willamette Valley  Willamette Valley  Paul Gregutt
#
#   taster_twitter_handle                                          title  \
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine   Rainstorm 2013 Pinot Gris (Willamette Valley)
#
#           variety               winery  naujas_stulpelis  description_len  \
# 1  Portuguese Red  Quinta dos Avidagos             13.05              227
# 2      Pinot Gris            Rainstorm             12.18              186
#
#    description_words           place
# ...

# %% [markdown]
# ## rename

# %%
df = df.rename(columns={'taster_name' : 'taster', 'taster_twitter_handle' : 'twitter_acc'})
df.head(2)
# Out:
#     country                                        description designation  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...         NaN
#
#    points  price province           region_1           region_2        taster  \
# 1      87   15.0    Douro                NaN                NaN    Roger Voss
# 2      87   14.0   Oregon  Willamette Valley  Willamette Valley  Paul Gregutt
#
#    twitter_acc                                          title         variety  \
# 1   @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  @paulgwine   Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery  naujas_stulpelis  description_len  description_words  \
# 1  Quinta dos Avidagos             13.05              227                 38
# 2            Rainstorm             12.18              186                 28
#
#             place
# ...

# %%
# map apjungia kelis dalykus

# %%
# galim pervadinti eilutes
df.rename(index={1:'first', 2:'second'}).iloc[1]
# Out:
# country                                                             US
# description          Tart and snappy, the flavors of lime flesh and...
# designation                                                        NaN
# points                                                              87
# price                                                             14.0
# province                                                        Oregon
# region_1                                             Willamette Valley
# region_2                                             Willamette Valley
# Tester                                                    Paul Gregutt
# twitter_acc                                                @paulgwine
# title                    Rainstorm 2013 Pinot Gris (Willamette Valley)
# variety                                                     Pinot Gris
# winery                                                       Rainstorm
# ...

# %% [markdown]
# ## dtypes

# %%
df['points'].dtype
# Out:
# dtype('int64')

# %%
print(df['description'].dtype)
# Out:
# object

# %%
df['price'].dtype
# Out:
# dtype('float64')

# %%
# pakeisti tipa

# %%
print(df['points'].astype('float64')) # nepakeicia org duomenu
df['points'] = df['points'].astype('float64')
# Out:
# 1         87.0
# 2         87.0
# 3         87.0
# 4         87.0
# 5         87.0
#           ...
# 129966    90.0
# 129967    90.0
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 111538, dtype: float64

# %%
df
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %%
df[df['region_2'].isna()]

# 65k eiluciu su region_2 reiksmes nan
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# 6          Italy  Here's a bright, informal red that opens with ...
# 7         France  This dry and restrained wine offers spice in p...
# ...          ...                                                ...
# 129965    France  While it's rich, this beautiful dry wine also ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 1                                     Avidagos      87   15.0
# ...

# %%
# jeigu nenorime, kad butu nan reiksmes, galime jas uzpildyti nurodytom reiksmes

# fillna uzpildo nan reiksmes pagal nurodyta verte

df['region_2'].fillna('Not specified') # duoda nauja vaizda, bet neperraso
# Out:
# 1             Not specified
# 2         Willamette Valley
# 3             Not specified
# 4         Willamette Valley
# 5             Not specified
#                 ...
# 129966        Not specified
# 129967         Oregon Other
# 129968        Not specified
# 129969        Not specified
# 129970        Not specified
# Name: region_2, Length: 111538, dtype: object

# %%
regions_2 = df['region_2'].fillna('Not specified')
# df['region_2'].fillna('Not specified', inplace=True) # same as above

# %%
# ar domejimasis kazkokia sritimi dideja
# kai susirandi duomenis, turi issikelti kazkoki tiksla, hipoteze, pvz, nori issiaiskinti
# ar kyla kaina per pastaruosius metus ir tt, isanalizuoti tuos duomenis ir# pateikti
# argumentus, kodel yra vienaip ar kitaip
# galima prognozuoti i ateiti
# gauti duomenis, isanalizuoti ir padaryti isvadas

# didzioji dalis duomenu suradimas ir ju isvalymas
# 7p - kaip pasikartojancias reiksmes istrinti, kaip kur nera duomenu svarbiu kaip pasalinti,
# apsidoroti duomenis, tureti ko reikia, vizualizavimas ir grafikai daug neuztruks,
# nebent prognoze, klasifikavimas ir tt.

# galima duomenis issisaugoti sql duombazej, tada per pandas nuskaityti duomenis nuo sql
# duombazes tiesiai
# galima pasiimti duomenis is sql, apdoroti juos su python ir tada vizualizuoti per power bi
# jeigu nenori power bi, galima tiesiai jupyter notebooke viska vizualizuoti.

# %%
regions_2
# Out:
# 1             Not specified
# 2         Willamette Valley
# 3             Not specified
# 4         Willamette Valley
# 5             Not specified
#                 ...
# 129966        Not specified
# 129967         Oregon Other
# 129968        Not specified
# 129969        Not specified
# 129970        Not specified
# Name: region_2, Length: 111538, dtype: object

# %%
# koreguoti lenteleje esancius duomenis

df.head(2)
# Out:
#     country                                        description designation  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...    Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...         NaN
#
#    points  price province           region_1           region_2        taster  \
# 1      87   15.0    Douro                NaN                NaN    Roger Voss
# 2      87   14.0   Oregon  Willamette Valley  Willamette Valley  Paul Gregutt
#
#    twitter_acc                                          title         variety  \
# 1   @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  @paulgwine   Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery  naujas_stulpelis  description_len  description_words  \
# 1  Quinta dos Avidagos             13.05              227                 38
# 2            Rainstorm             12.18              186                 28
#
#             place
# ...

# %%
# pakeisti stulpelio verte
df['twitter_acc'].replace('@vossroger', 'me')
# Out:
# 1                  me
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
# 5         @wineschach
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968             me
# 129969             me
# 129970             me
# Name: twitter_acc, Length: 111538, dtype: object
